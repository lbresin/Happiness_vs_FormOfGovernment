# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# Democracy Index Data
# Source: https://en.wikipedia.org/wiki/Democracy_Index#cite_note-index2019-7
df_dem = pd.read_csv('democracy_index.csv', index_col=0)
df_dem = df_dem.set_index('Country')
df_dem
# Out:
#                                   Score  Electoral process and pluralism  \
# Country
# Norway                             9.87                            10.00
# Iceland                            9.58                            10.00
# Sweden                             9.39                             9.58
# New Zealand                        9.26                            10.00
# Finland                            9.25                            10.00
# ...                                 ...                              ...
# Chad                               1.61                             0.00
# Syria                              1.43                             0.00
# Central African Republic           1.32                             1.25
# Democratic Republic of the Congo   1.13                             0.00
# North Korea                        1.08                             0.00
#
#                                   Functioning of government  \
# Country
# ...

# %%
# World Happiness Report 2019
# Source: https://worldhappiness.report/ed/2019/
df_happy = pd.read_csv('happiness_index.csv', index_col=0)
df_happy = df_happy.set_index('Country')
df_happy
# Out:
#                           Score  GDP per capita  Social support  \
# Country
# Finland                   7.769           1.340           1.587
# Denmark                   7.600           1.383           1.573
# Norway                    7.554           1.488           1.582
# Iceland                   7.494           1.380           1.624
# Netherlands               7.488           1.396           1.522
# ...                         ...             ...             ...
# Rwanda                    3.334           0.359           0.711
# Tanzania                  3.231           0.476           0.885
# Afghanistan               3.203           0.350           0.517
# Central African Republic  3.083           0.026           0.000
# South Sudan               2.853           0.306           0.575
#
#                           Healthy life expectancy  \
# Country
# Finland                                     0.986
# Denmark                                     0.996
# ...

# %%
# Environmental Performance Index 2020
# Source: https://epi.yale.edu/downloads
df_epi = pd.read_csv('environmental_performance_index.csv', index_col=0)
df_epi = df_epi.set_index('country')
df_epi
# Out:
#                       iso  EPI.new  HLT.new  AIR.new  PMD.new  HAD.new  \
# country
# Afghanistan           AFG     25.5     20.0     17.7     25.4      7.3
# Angola                AGO     29.7     20.4     26.8     32.6     17.8
# Albania               ALB     49.0     44.5     41.2     44.2     34.6
# United Arab Emirates  ARE     55.6     55.2     48.6     13.9    100.0
# Argentina             ARG     52.2     60.2     56.9     54.7     60.9
# ...                   ...      ...      ...      ...      ...      ...
# Vanuatu               VUT     28.9     26.7     28.6     42.2      5.9
# Samoa                 WSM     37.3     42.4     33.4     46.3     14.4
# South Africa          ZAF     43.1     31.1     28.9     22.7     36.2
# Zambia                ZMB     34.7     21.0     27.0     36.9     12.5
# Zimbabwe              ZWE     37.0     22.5     27.2     38.2     10.2
#
#                       OZD.new  H2O.new  USD.new  UWD.new  ...  LCB.rnk.new  \
# ...

# %%
# Merge the two data sets
df = df_happy.merge(df_dem, how='inner',right_index=True, left_index=True)
df2 = df.merge(df_epi, how='inner', right_index=True, left_index=True)

# %%
fig, ax = plt.subplots(figsize=(13/2.5, 13/2.5))


ax.scatter(df[df['Regime type'] == 'Full democracy']['Score_y'], df[df['Regime type'] == 'Full democracy'].Score_x, color='#0571b0', label='Full democracy', alpha=.7, edgecolors='none')
ax.scatter(df[df['Regime type'] == 'Flawed democracy']['Score_y'], df[df['Regime type'] == 'Flawed democracy'].Score_x, color='#92c5de', label='Flawed democracy', alpha=.7, edgecolors='none')
ax.scatter(df[df['Regime type'] == 'Hybrid regime']['Score_y'], df[df['Regime type'] == 'Hybrid regime'].Score_x, color='#f4a582', label='Hybrid regime', alpha=.7, edgecolors='none')
ax.scatter(df[df['Regime type'] == 'Authoritarian']['Score_y'], df[df['Regime type'] == 'Authoritarian'].Score_x, color='#ca0020', label='Authoritarian', alpha=.7, edgecolors='none')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)

# label China
country='China'
ax.scatter(df.loc[country]['Score_y'], df.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df.loc[country]['Score_y']
y_loc = df.loc[country]['Score_x']
ax.plot([x_loc, x_loc+0.12], [y_loc, y_loc-0.35], linewidth=0.25, color='black')
ax.plot([x_loc+0.12, x_loc+0.15], [y_loc-0.35, y_loc-0.35], linewidth=0.25, color='black')
ax.text(x_loc+0.15, y_loc-0.40,country)

# label China
country='United States of America'
ax.scatter(df.loc[country]['Score_y'], df.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df.loc[country]['Score_y']
y_loc = df.loc[country]['Score_x']
ax.plot([x_loc, x_loc+0.55], [y_loc, y_loc-0.35], linewidth=0.25, color='black')
ax.plot([x_loc+0.55, x_loc+0.58], [y_loc-0.35, y_loc-0.35], linewidth=0.25, color='black')
ax.text(x_loc+0.58, y_loc-0.40,'USA')

# label China
country='Norway'
ax.scatter(df.loc[country]['Score_y'], df.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df.loc[country]['Score_y']
y_loc = df.loc[country]['Score_x']
ax.plot([x_loc, x_loc+0.12], [y_loc, y_loc-0.35], linewidth=0.25, color='black')
ax.plot([x_loc+0.12, x_loc+0.15], [y_loc-0.35, y_loc-0.35], linewidth=0.25, color='black')
ax.text(x_loc+0.15, y_loc-0.40,country)

# label China
country='Germany'
ax.scatter(df.loc[country]['Score_y'], df.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df.loc[country]['Score_y']
y_loc = df.loc[country]['Score_x']
ax.plot([x_loc, x_loc+0.12], [y_loc, y_loc-0.25], linewidth=0.25, color='black')
ax.plot([x_loc+0.12, x_loc+0.15], [y_loc-0.25, y_loc-0.25], linewidth=0.25, color='black')
ax.text(x_loc+.12, y_loc-0.30,country)

ax.set_ylabel('Happiness Index')
ax.set_xlabel('Democracy Index')
plt.legend(frameon=False)
plt.savefig('happiness_vs_democracy.png', dpi=300)
plt.savefig('happiness_vs_democracy.pdf', dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="520">

# %%
score_happiness = df[df['Regime type'] == 'Authoritarian'].Score_x
score_dem = df[df['Regime type'] == 'Authoritarian'].Score_y

fig, ax = plt.subplots(figsize=(13/2.5, 13/2.5))


ax.scatter(df[df['Regime type'] == 'Full democracy']['GDP per capita'], df[df['Regime type'] == 'Full democracy'].Score_x, color='#0571b0', label='Full democracy', alpha=.7, edgecolors='none')
ax.scatter(df[df['Regime type'] == 'Flawed democracy']['GDP per capita'], df[df['Regime type'] == 'Flawed democracy'].Score_x, color='#92c5de', label='Flawed democracy', alpha=.7, edgecolors='none')
ax.scatter(df[df['Regime type'] == 'Hybrid regime']['GDP per capita'], df[df['Regime type'] == 'Hybrid regime'].Score_x, color='#f4a582', label='Hybrid regime', alpha=.7, edgecolors='none')
ax.scatter(df[df['Regime type'] == 'Authoritarian']['GDP per capita'], df[df['Regime type'] == 'Authoritarian'].Score_x, color='#ca0020', label='Authoritarian', alpha=.7, edgecolors='none')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)

# label China
country='China'
ax.scatter(df.loc[country]['GDP per capita'], df.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df.loc[country]['GDP per capita']
y_loc = df.loc[country]['Score_x']
ax.plot([x_loc, x_loc+0.12], [y_loc, y_loc-0.35], linewidth=0.25, color='black')
ax.plot([x_loc+0.12, x_loc+0.15], [y_loc-0.35, y_loc-0.35], linewidth=0.25, color='black')
ax.text(x_loc+0.15, y_loc-0.40,country)

# label China
country='United States of America'
ax.scatter(df.loc[country]['GDP per capita'], df.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df.loc[country]['GDP per capita']
y_loc = df.loc[country]['Score_x']
ax.plot([x_loc, x_loc+0.12], [y_loc, y_loc-0.35], linewidth=0.25, color='black')
ax.plot([x_loc+0.12, x_loc+0.15], [y_loc-0.35, y_loc-0.35], linewidth=0.25, color='black')
ax.text(x_loc+0.15, y_loc-0.40,'USA')

# label China
country='Norway'
ax.scatter(df.loc[country]['GDP per capita'], df.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df.loc[country]['GDP per capita']
y_loc = df.loc[country]['Score_x']
ax.plot([x_loc, x_loc+0.12], [y_loc, y_loc-0.35], linewidth=0.25, color='black')
ax.plot([x_loc+0.12, x_loc+0.15], [y_loc-0.35, y_loc-0.35], linewidth=0.25, color='black')
ax.text(x_loc+0.15, y_loc-0.40,country)

# label China
country='Germany'
ax.scatter(df.loc[country]['GDP per capita'], df.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df.loc[country]['GDP per capita']
y_loc = df.loc[country]['Score_x']
ax.plot([x_loc, x_loc-0.12], [y_loc, y_loc-0.35], linewidth=0.25, color='black')
ax.plot([x_loc-0.12, x_loc-0.15], [y_loc-0.35, y_loc-0.35], linewidth=0.25, color='black')
ax.text(x_loc-0.35, y_loc-0.40,country)

ax.set_ylabel('Happiness Index')
ax.set_xlabel('GDP per capita')
plt.legend(frameon=False)
plt.savefig('happiness_vs_gdp.png', dpi=300)
plt.savefig('happiness_vs_gdp.pdf', dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="520">

# %%
fig, ax = plt.subplots(figsize=(13/2.5, 13/2.5))


ax.scatter(df2[df2['Regime type'] == 'Full democracy']['EPI.new'], df2[df2['Regime type'] == 'Full democracy'].Score_x, color='#0571b0', label='Full democracy', alpha=.7, edgecolors='none')
ax.scatter(df2[df2['Regime type'] == 'Flawed democracy']['EPI.new'], df2[df2['Regime type'] == 'Flawed democracy'].Score_x, color='#92c5de', label='Flawed democracy', alpha=.7, edgecolors='none')
ax.scatter(df2[df2['Regime type'] == 'Hybrid regime']['EPI.new'], df2[df2['Regime type'] == 'Hybrid regime'].Score_x, color='#f4a582', label='Hybrid regime', alpha=.7, edgecolors='none')
ax.scatter(df2[df2['Regime type'] == 'Authoritarian']['EPI.new'], df2[df2['Regime type'] == 'Authoritarian'].Score_x, color='#ca0020', label='Authoritarian', alpha=.7, edgecolors='none')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)

# label China
country='China'
ax.scatter(df2.loc[country]['EPI.new'], df2.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df2.loc[country]['EPI.new']
y_loc = df2.loc[country]['Score_x']
ax.plot([x_loc, x_loc+0.12], [y_loc, y_loc-0.35], linewidth=0.25, color='black')
ax.plot([x_loc+0.12, x_loc+0.15], [y_loc-0.35, y_loc-0.35], linewidth=0.25, color='black')
ax.text(x_loc+0.15, y_loc-0.40,country)

# label China
country='United States of America'
ax.scatter(df2.loc[country]['EPI.new'], df2.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df2.loc[country]['EPI.new']
y_loc = df2.loc[country]['Score_x']
ax.plot([x_loc, x_loc+0.12], [y_loc, y_loc-0.35], linewidth=0.25, color='black')
ax.plot([x_loc+0.12, x_loc+0.15], [y_loc-0.35, y_loc-0.35], linewidth=0.25, color='black')
ax.text(x_loc+0.15, y_loc-0.40,'USA')

# label China
country='Norway'
ax.scatter(df2.loc[country]['EPI.new'], df2.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df2.loc[country]['EPI.new']
y_loc = df2.loc[country]['Score_x']
ax.plot([x_loc, x_loc+0.12], [y_loc, y_loc-0.35], linewidth=0.25, color='black')
ax.plot([x_loc+0.12, x_loc+0.15], [y_loc-0.35, y_loc-0.35], linewidth=0.25, color='black')
ax.text(x_loc+0.15, y_loc-0.40,country)

# label China
country='Germany'
ax.scatter(df2.loc[country]['EPI.new'], df2.loc[country]['Score_x'],facecolors='none',edgecolors='black',  linewidth=2)
x_loc = df2.loc[country]['EPI.new']
y_loc = df2.loc[country]['Score_x']
ax.plot([x_loc, x_loc+0.12], [y_loc, y_loc-0.35], linewidth=0.25, color='black')
ax.plot([x_loc+0.12, x_loc+0.15], [y_loc-0.35, y_loc-0.35], linewidth=0.25, color='black')
ax.text(x_loc+0.15, y_loc-0.40,country)

ax.set_ylabel('Happiness Index')
ax.set_xlabel('Environmental Performance Index')
plt.legend(frameon=False)
plt.savefig('happiness_vs_epi.png', dpi=300)
plt.savefig('happiness_vs_epi.pdf', dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="520">
